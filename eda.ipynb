# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammad-qethama/eda_python/blob/master/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Core packages for data analysis
# !pip install  pandas numpy

# Visualization libraries
# !pip install plotly
# !pip install seaborn
# !pip install matplotlib

# Additional useful packages
# !pip install scipy     # for statistical analysis
# !pip install ydata-profiling    # for automated EDA reports (formerly pandas-profiling)
# !pip install sweetviz  # another automated EDA tool
# !pip install dtale     # interactive visualization and analysis
# !pip install missingno # for visualizing missing data
# %pip install plotly
# %pip install seaborn
# %pip install matplotlib

# # Additional useful packages
# %pip install scipy     # for statistical analysis
# %pip install ydata-profiling    # for automated EDA reports (formerly pandas-profiling)
# %pip install sweetviz  # another automated EDA tool
# %pip install dtale     # interactive visualization and analysis
# %pip install missingno # for visualizing missing data
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 35.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 61.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=02d52a5d8be351f895f274ffea01b88aa85e8517ed5c759826b1d1ee0d533e06
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 50.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('./cleaned_data/total_eda.csv')
df.head()
# Out:
#   location_iso  smokers_percentage  deaths toll with smoking as risk  \
# 0  Afghanistan                23.3                       6253.962276
# 1      Albania                22.4                       6253.962276
# 2      Algeria                21.0                       6253.962276
# 3      Andorra                31.8                       4030.615487
# 4    Argentina                24.5                       4030.615487
#
#    YLLs (years of life lost)  smoking_deaths_percentage(total only)
# 0               203277.42780                                  0.025
# 1               203277.42780                                  0.146
# 2               203277.42780                                  0.067
# 3                79400.01996                                  0.105
# 4                79400.01996                                  0.077

# %%
# %pwd
# Out:
# '/content'

# %%
profile = ProfileReport(df, title="Profiling Report")
profile.to_file("report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
